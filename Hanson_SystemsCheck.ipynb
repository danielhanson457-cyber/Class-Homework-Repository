# %% [markdown]
# # Systems Check
#
# ## What I Hope to Get Out of This Class
#
# ### My Goals
#
# I hope to gain a better understanding of information systems and how they are used in the world. I also want to become more comfortable using Jupyter Notebook and other technology that can help me in the future.

# %% [markdown]
# ## Second Part of Assignment THE LIST
#
# 1. Improve my understanding of information systems.
# 2. Become more comfortable using Jupyter Notebook.
# 4. Learn skills that I can use in my future career.

# %% [markdown]
# ![My Image](download.jpeg)
